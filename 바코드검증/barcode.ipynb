# %%
import pandas as pd

# %%
barcode_df = pd.read_excel("바코드확인용.xlsx")

# %%
barcode_df.head()
# Out:
#     사용  품목코드               품목명                        이전품목명   단위         규격정보  \
# 0  YES   1.0               배송료                          배송료  NaN          NaN
# 1  YES   6.0   GARUDA 땅콩과자 계란맛  가루다 계란맛 코팅 땅콩(KACANG TELUR)   EA   230G X 1EA
# 2  YES   9.0       GARUDA 까장쿨릿     가루다까장쿨릿(ROASTED PEANUTS)   EA   180G X 1EA
# 3  YES  10.0  TRUNG THANH 가지피클                    가지피클(까무이)  BOX  500G X 12EA
# 4  YES  11.0  TRUNG THANH 가지피클                    가지피클(까무이)   EA   500G X 1EA
#
#      위치1    위치2     B동 과세/면세 수입/매입명            바코드    냉동/냉장명    국가명  \
# 0    NaN    NaN    NaN    과세    NaN            NaN  Dry 상온보관     기타
# 1  L32-1  L32-2  HF-94    과세   샤론푸드  8992775212103  Dry 상온보관  인도네시아
# 2  L33-1    NaN  HF-93    과세   샤론푸드  8992775110126  Dry 상온보관  인도네시아
# 3  J02-1  J02-2  V29-1    과세    오티엘  8934752030010  Dry 상온보관    베트남
# 4  J02-1  J02-2  HG-68    과세    오티엘  8934752030010  Dry 상온보관    베트남
#
#            바코드숫자           박스바코드
# 0            NaN        99999999
# ...
