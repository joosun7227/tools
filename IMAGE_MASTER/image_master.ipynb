# %%
import os
import pandas as pd

# 이미지 경로 설정
path = r'C:\Users\jusun\OneDrive\문서\3yejoo\그라미스Gromise\상품구성\그라미스상품사진\상품사진찍기'

# 이미지 파일명 추출
files = [f for f in os.listdir(path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp'))]

# 엑셀로 저장
df = pd.DataFrame({'이미지명': files})
save_path = r'C:\Users\jusun\OneDrive\문서\3yejoo\그라미스Gromise\상품구성\그라미스상품사진\이미지목록.xlsx'
df.to_excel(save_path, index=False)
